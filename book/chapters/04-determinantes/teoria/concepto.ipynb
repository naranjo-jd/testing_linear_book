# %% [markdown]
# # 📐 Concepto de Determinante
#
# El **determinante** es una función que asigna a cada matriz cuadrada un número real.
# Ese número captura información profunda sobre la matriz:
#
# - si es invertible,
# - cuánto escala áreas o volúmenes,
# - si cambia o preserva la orientación,
# - si aplasta el espacio a una dimensión menor,
# - si las columnas son linealmente independientes.
#
# El determinante es una herramienta esencial en álgebra lineal, cálculo multivariable, física, gráficos computacionales y optimización.
#
# ---
#
# # 1. 🔎 ¿Qué es el determinante?
#
# Para una matriz cuadrada $A \in \mathbb{R}^{n \times n}$, su determinante se denota como:
#
# $$
# \det(A) \quad \text{o} \quad |A|.
# $$
#
# Es un **funcional único** que cumple propiedades muy importantes (linealidad por filas, alternancia, normalización), y esas propiedades determinan completamente su definición.
#
# ---
#
# # 2. 🌍 Interpretación geométrica
#
# El determinante mide el **cambio de volumen** que produce la transformación lineal:
#
# $$
# T_A(\mathbf{x}) = A\mathbf{x}.
# $$
#
# ### En $\mathbb{R}^2$
# - Si $|\det$A)|$ = área del paralelogramo formado por las columnas de $A$.
# - Si $\det(A) = 0$: el plano se aplasta en una línea.
# - Si $\det(A) > 0$: preserva orientación.
# - Si $\det(A) < 0$: invierte orientación (reflejo).
#
# ### En $\mathbb{R}^3$
# - $|\det(A)|$ = volumen del paralelepípedo formado por las columnas.
# - $\det(A)=0$: aplasta el espacio a un plano o recta.
#
# ### En general
# $$
# |\det(A)| = \text{factor de escala de volumen en } \mathbb{R}^n.
# $$
#
# ---
#
# ## 💡 Ejemplo geométrico en 2D
#
# Si
#
# $$
# A=
# \begin{pmatrix}
# 2 & 0 \\
# 1 & 3 \\
# \end{pmatrix}
# $$
#
# sus columnas son los vectores $(2,1)$ y $(0,3)$.
# El paralelogramo formado por ellos tiene área:
#
# $$
# |\det(A)| = |(2)(3) - (0)(1)| = 6.
# $$
#
# → La transformación **multiplica el área por 6**.
#
# ---
#
# ## 💻 Visualización en Python

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.array([[2,0],
              [1,3]])

# Vectores columna
v1 = A[:,0]
v2 = A[:,1]

# Generar paralelogramo
P = np.array([[0,0], v1, v1+v2, v2, [0,0]])

plt.figure(figsize=(6,6))
plt.plot(P[:,0], P[:,1], 'r-', linewidth=2)
plt.quiver(0,0,v1[0],v1[1], angles='xy', scale_units='xy', scale=1, color='blue')
plt.quiver(0,0,v2[0],v2[1], angles='xy', scale_units='xy', scale=1, color='green')

plt.axhline(0,color='black'); plt.axvline(0,color='black')
plt.gca().set_aspect('equal')
plt.title("Paralelogramo formado por columnas de A (área = |det(A)|)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       4 A = np.array([[2,0],
#       5               [1,3]])
#       7 # Vectores columna
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ---
#
# # 3. 🧮 Interpretación algebraica
#
# El determinante también mide:
#
# ### ✔️ Independencia lineal
#
# $
# \det(A) = 0 \iff \text{las columnas (o filas) son dependientes}.
# $
#
# ### ✔️ Invertibilidad
#
# $
# A \text{ invertible} \iff \det(A) \neq 0.
# $
#
# ### ✔️ Efecto de operaciones básicas
#
# * Intercambiar dos filas → cambia el signo.
# * Multiplicar una fila por un escalar (\alpha) → multiplica el determinante por (\alpha).
# * Sumar a una fila otra fila multiplicada → NO lo modifica.
#
# ---
#
# ## 📌 Para matrices pequeñas
#
# ### 2×2
#
# $
# \det\begin{pmatrix}
# a & b \ c & d
# \end{pmatrix} = ad - bc.
# $
#
# ### 3×3 (Regla de Sarrus)
#
# $
# \det(A) =
# a(ei - fh) - b(di - fg) + c(df - eg).
# $
#
# ---
#
# # 4. 🧮 Interpretación como expansión por cofactores
#
# Para cualquier fila (i):
#
# $
# \det(A) = \sum_{j=1}^n (-1)^{i+j} a_{ij}, M_{ij},
# $
#
# donde $M_{ij}$ es el menor (determinante del submatriz).
#
# Esto generaliza los determinantes a dimensión arbitraria.
#
# ---
#
# # 5. 🧪 Cálculo computacional del determinante
#
# ## Con NumPy

# %% [markdown]
# Para la matriz $3 \times 3$:
#
# $$A = \begin{pmatrix} 2 & 1 & 0 \\ 1 & 3 & 2 \\ 0 & 1 & 4 \end{pmatrix}$$
#
# Calculando el determinante:
#
# $$\det(A) = 2 \cdot \det\begin{pmatrix} 3 & 2 \\ 1 & 4 \end{pmatrix} - 1 \cdot \det\begin{pmatrix} 1 & 2 \\ 0 & 4 \end{pmatrix} + 0$$
#
# $$= 2 \cdot (12 - 2) - 1 \cdot (4 - 0) = 2 \cdot 10 - 4 = 20 - 4 = 16$$

# %% [markdown]
# ---
#
# ## Con SymPy (exacto)

# %%
import sympy as sp

A = sp.Matrix([[2,1,0],
                [1,3,2],
                [0,1,4]])

A.det()

# %% [markdown]
# ---
#
# # 6. 🔁 Relación con transformaciones lineales
#
# Toda matriz cuadrada representa una transformación lineal $T_A$.
# El determinante describe su efecto global:
#
# | $\det(A)$ | Interpretación       |   |                                  |
# | --------- | -------------------- | - | -------------------------------- |
# | $>0$      | preserva orientación |   |                                  |
# | $<0$      | invierte orientación |   |                                  |
# | $=0$      | aplasta el espacio   |   |                                  |
# |           | $\det(A)$            |   | factor de escala de volumen/área |
#
# Además:
#
# * Si $\det(A)=1$: transformación rigid-body (preserva volumen)
# * Si $\det(A)=-1$: transformación rígida con reflexión
#
# ---
#
# # 7. ✨ Ejemplos completos
#
# ### Ejemplo 1: Área en 2D

# %% [markdown]
# Para la matriz $A = \begin{pmatrix} 3 & 1 \\ 1 & 2 \end{pmatrix}$:
#
# $$\det(A) = 3 \cdot 2 - 1 \cdot 1 = 6 - 1 = 5$$
#
# El área del paralelogramo original se multiplica por este factor.

# %% [markdown]
# ### Ejemplo 2: Volumen en 3D

# %% [markdown]
# Para la matriz:
#
# $$A = \begin{pmatrix} 1 & 2 & 1 \\ 0 & 1 & 3 \\ 2 & 0 & 1 \end{pmatrix}$$
#
# El volumen del paralelepípedo formado por los vectores columna es:
#
# $$V = |\det(A)| = |1(1 \cdot 1 - 3 \cdot 0) - 2(0 \cdot 1 - 3 \cdot 2) + 1(0 \cdot 0 - 1 \cdot 2)|$$
#
# $$= |1 - 2(-6) + 1(-2)| = |1 + 12 - 2| = |11| = 11$$

# %% [markdown]
# ---
#
# # 8. 🧰 Funciones reusables

# %%
def determinante(A):
    """Calcula el determinante usando NumPy."""
    return np.linalg.det(np.array(A, dtype=float))

def escala_volumen(A):
    """Devuelve el factor de escalamiento absoluto."""
    return abs(np.linalg.det(np.array(A, dtype=float)))

def es_invertible(A):
    return not np.isclose(np.linalg.det(np.array(A)), 0)

# %% [markdown]
# ---
#
# # 9. 🧩 Ejercicios sugeridos
#
# ### **1. Área y volumen**
#
# Crea una función que:
#
# * tome las columnas de una matriz,
# * grafique el paralelogramo/paralelepípedo,
# * muestre el área o volumen usando el determinante.
#
# ---
#
# ### **2. Efecto de operaciones elementales**
#
# Implementa funciones que:
#
# * intercambien filas,
# * multipliquen filas,
# * sumen múltiplos de filas,
#
# y verifiquen cómo cambia el determinante en cada caso.
#
# ---
#
# ### **3. Comparación NumPy vs SymPy**
#
# Evalúa determinantes de matrices grandes y compara:
#
# * exactitud,
# * tiempo de ejecución.
#
# ---
#
# ### **4. Generador de transformaciones**
#
# Genera matrices con:
#
# * reflexión,
# * rotación,
# * escala,
#
# y analiza su determinante para interpretar la transformación.
#
# ---
#
# ### **5. Determinantes simbólicos**
#
# Escribe una función con SymPy que compute:
#
# $$
# \det(tI - A)
# $$
#
# para obtener el polinomio característico.
#
# ---
#
# # 📚 Conclusión
#
# El determinante es mucho más que un número:
# es una herramienta que describe **cómo una matriz transforma el espacio**.
#
# * En 2D mide áreas,
# * en 3D mide volúmenes,
# * en nD mide hiper-volúmenes,
# * indica invertibilidad,
# * detecta dependencia lineal,
# * clasifica transformaciones.
#
# > **“El determinante es la lupa que revela el efecto global de una transformación lineal.”**
#
# ---
#
# 👉 **Siguiente tema:** `determinante_calculo.ipynb`
