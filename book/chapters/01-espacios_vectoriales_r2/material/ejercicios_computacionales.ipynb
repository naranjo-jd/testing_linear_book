# %% [markdown]
# # Ejercicio computacional

# %% [markdown]
# 1. Defina los vectores $\mathbf{v}=(1,3)$ y $\mathbf{w}=(2,5)$ en Python utilizando NumPy y realice las siguientes operaciones:
#
#     a) Calcule $3.0(\mathbf{v}+\mathbf{w})$ y $3.0\mathbf{v}+3.0\mathbf{w}$, y verifique que son iguales.
#
#     b) Calcule $(5+1/3)\mathbf{v}$ y $5\mathbf{v}+\frac{1}{3}\mathbf{v}$, y verifique que son iguales.
#
#     c) Calcule $1.\mathbf{v}$ y verifique que es igual a $\mathbf{v}$.

# %%
# Aqui podras realizar los ejercicios

# %% [markdown]
# 2. Defina la recta $\mathbf{r}$ en Python utilizando NumPy con la ecuación vectorial $\mathbf{r}(t) = (1, -2) + t(-3, 4)$ para $t\in \mathbb{R}$. Luego, realice las siguientes tareas:
#
#     a) Encuentre la ecuación cartesiana de la forma $ax + by = c$.
#
#     b) Determine si el punto $(10, -14)$ pertenece a la recta $\mathbf{r}$.

# %%
# Aqui podras realizar los ejercicios
