# %% [markdown]
# # Ejercicios del Capítulo
#
# Esta sección recopila ejercicios de práctica sobre los temas cubiertos en este capítulo: espacios vectoriales en $\mathbb{R}^2$, combinaciones lineales, independencia lineal, subespacios, rectas y producto punto.
#
# Los ejercicios están organizados en cuatro secciones:
#
# 1. **Ejercicios Teóricos**: problemas para resolver a mano, enfocados en conceptos y cálculos básicos.
# 2. **Ejercicios Computacionales**: problemas que requieren programación en Python con NumPy.
# 3. **Problemas de Aplicación**: situaciones del mundo real que usan los conceptos del capítulo.
# 4. **Desafíos**: problemas avanzados que requieren demostraciones o múltiples pasos.
#
# La dificultad se indica con estrellas:
# - * Básico
# - ** Intermedio
# - *** Desafiante

# %% [markdown]
# ## 1. Ejercicios Teóricos

# %% [markdown]
# ### Vectores y Operaciones

# %% [markdown]
# :::{admonition} Ejercicio 1.1 *
# :class: tip
#
# Dados los vectores $\mathbf{u} = (3, -1)$ y $\mathbf{v} = (-2, 4)$, calcule:
#
# a) $\mathbf{u} + \mathbf{v}$
#
# b) $2\mathbf{u} - 3\mathbf{v}$
#
# c) $\|\mathbf{u}\|$ y $\|\mathbf{v}\|$
#
# d) Un vector unitario en la dirección de $\mathbf{u}$
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.2 *
# :class: tip
#
# Encuentre los valores de $x$ e $y$ tales que:
#
# \((x + 2, 3y - 1) = (5, 8)\)
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.3 **
# :class: tip
#
# Sean $\mathbf{v} = (1, 3)$, $\mathbf{w} = (2, 5)$ y $\mathbf{u} = (3, 8)$. Verifique numéricamente las siguientes propiedades:
#
# a) $3(\mathbf{v} + \mathbf{w}) = 3\mathbf{v} + 3\mathbf{w}$ (Distributividad del escalar sobre la suma de vectores)
#
# b) $(5 + \frac{1}{3})\mathbf{v} = 5\mathbf{v} + \frac{1}{3}\mathbf{v}$ (Distributividad de la suma de escalares)
#
# c) $1 \cdot \mathbf{v} = \mathbf{v}$ (Elemento neutro de la multiplicación escalar)
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.4 **
# :class: tip
#
# Escriba todas las propiedades (axiomas) que debe cumplir un espacio vectorial y verifique que $\mathbb{R}^2$ con la suma y multiplicación por escalar usuales las satisface.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.5 **
# :class: tip
#
# Determine si el conjunto $\mathbb{R}^2$ con las operaciones definidas como:
#
# - Suma: $(x_1, y_1) \oplus (x_2, y_2) = (x_1 + x_2, y_1 + y_2)$
# - Producto escalar: $c \odot (x, y) = (cx, 0)$
#
# forma un espacio vectorial. Justifique su respuesta indicando qué axiomas se cumplen o no.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.6 ***
# :class: tip
#
# Demuestre que para cualquier vector $\mathbf{v} \in \mathbb{R}^2$, se cumple que $0 \cdot \mathbf{v} = \mathbf{0}$, usando únicamente los axiomas de espacios vectoriales.
#
# :::{dropdown} Pista
# Use que $0 = 0 + 0$ y la propiedad distributiva.
# :::
# :::

# %% [markdown]
# ### Combinaciones Lineales

# %% [markdown]
# :::{admonition} Ejercicio 1.7 *
# :class: tip
#
# Exprese el vector $\mathbf{w} = (7, 11)$ como combinación lineal de $\mathbf{u} = (1, 2)$ y $\mathbf{v} = (3, 1)$.
#
# Es decir, encuentre escalares $a$ y $b$ tales que $\mathbf{w} = a\mathbf{u} + b\mathbf{v}$.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.8 **
# :class: tip
#
# ¿Es posible expresar el vector $\mathbf{w} = (1, 5)$ como combinación lineal de $\mathbf{u} = (2, 4)$ y $\mathbf{v} = (3, 6)$? Justifique su respuesta.
#
# :::{dropdown} Pista
# Observe que $\mathbf{v} = \frac{3}{2}\mathbf{u}$. ¿Qué implica esto sobre el espacio generado?
# :::
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.9 **
# :class: tip
#
# Determine el espacio generado (span) por los vectores $\mathbf{v}_1 = (1, 0)$ y $\mathbf{v}_2 = (0, 1)$. Describa geométricamente este conjunto.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.10 **
# :class: tip
#
# Determine el espacio generado (span) por el vector $\mathbf{v} = (3, -2)$. Describa geométricamente este conjunto.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.11 ***
# :class: tip
#
# Sea $S = \{(1, 2), (2, 4), (3, 6)\}$. Determine $\text{span}(S)$ y dé una descripción geométrica del conjunto.
#
# :::{dropdown} Pista
# Observe la relación entre los tres vectores.
# :::
# :::

# %% [markdown]
# ### Independencia Lineal

# %% [markdown]
# :::{admonition} Ejercicio 1.12 **
# :class: tip
#
# Determine si los siguientes conjuntos de vectores son linealmente independientes o dependientes:
#
# a) $\{(1, 2), (3, 4)\}$
#
# b) $\{(2, -4), (-1, 2)\}$
#
# c) $\{(0, 0), (1, 1)\}$
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.13 **
# :class: tip
#
# Encuentre el valor de $k$ para que los vectores $\mathbf{u} = (2, 3)$ y $\mathbf{v} = (4, k)$ sean linealmente dependientes.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.14 **
# :class: tip
#
# Usando el concepto de determinante, verifique si los vectores $\mathbf{u} = (5, -2)$ y $\mathbf{v} = (10, -4)$ son linealmente independientes.
#
# :::{dropdown} Pista
# Dos vectores en $\mathbb{R}^2$ son l.i. si y solo si el determinante de la matriz formada por ellos como columnas es distinto de cero.
# :::
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.15 ***
# :class: tip
#
# Demuestre que si $\{\mathbf{u}, \mathbf{v}\}$ es un conjunto linealmente independiente en $\mathbb{R}^2$, entonces $\{\mathbf{u} + \mathbf{v}, \mathbf{u} - \mathbf{v}\}$ también es linealmente independiente.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.16 ***
# :class: tip
#
# ¿Pueden tres vectores no nulos de $\mathbb{R}^2$ ser linealmente independientes? Justifique su respuesta.
# :::

# %% [markdown]
# ### Subespacios

# %% [markdown]
# :::{admonition} Ejercicio 1.17 **
# :class: tip
#
# Determine cuáles de los siguientes conjuntos son subespacios de $\mathbb{R}^2$. Justifique su respuesta verificando las condiciones de subespacio.
#
# a) $W_1 = \{(x, y) \in \mathbb{R}^2 : y = 2x\}$
#
# b) $W_2 = \{(x, y) \in \mathbb{R}^2 : x + y = 1\}$
#
# c) $W_3 = \{(x, y) \in \mathbb{R}^2 : xy = 0\}$
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.18 **
# :class: tip
#
# Sea el conjunto $W = \{(x, y) \in \mathbb{R}^2 : 3x - y = 0\}$.
#
# a) Demuestre que $W$ es un subespacio de $\mathbb{R}^2$.
#
# b) Encuentre un vector que genere $W$.
#
# c) ¿Cuál es la dimensión de $W$?
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.19 **
# :class: tip
#
# Considere la recta $\mathbf{r}(t) = t(2, 3) + (0, b)$ para $t \in \mathbb{R}$.
#
# ¿Para qué valor(es) de $b$ el conjunto de puntos de esta recta forma un subespacio vectorial de $\mathbb{R}^2$? Justifique usando la propiedad del vector cero.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.20 ***
# :class: tip
#
# Sea $U = \{(x, 0) : x \in \mathbb{R}\}$ y $V = \{(0, y) : y \in \mathbb{R}\}$.
#
# a) Demuestre que $U$ y $V$ son subespacios de $\mathbb{R}^2$.
#
# b) ¿Es $U \cup V$ un subespacio de $\mathbb{R}^2$? Justifique.
#
# c) ¿Qué puede decir sobre $U \cap V$?
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.21 ***
# :class: tip
#
# Clasifique todos los posibles subespacios de $\mathbb{R}^2$ y dé una descripción geométrica de cada tipo.
# :::

# %% [markdown]
# ### Rectas

# %% [markdown]
# :::{admonition} Ejercicio 1.22 *
# :class: tip
#
# Sea la recta $\mathbf{r}$ con ecuación vectorial $\mathbf{r}(t) = (1, -2) + t(-3, 4)$ para $t \in \mathbb{R}$.
#
# a) Encuentre la ecuación cartesiana de la forma $ax + by = c$.
#
# b) Determine si el punto $(10, -14)$ pertenece a la recta.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.23 **
# :class: tip
#
# Encuentre una ecuación paramétrica vectorial para la recta que pasa por $A = (-5, 1)$ y $B = (2, -1)$, tal que $\mathbf{r}(0) = A$ y $\mathbf{r}(1) = B$.
#
# Encuentre también otra parametrización distinta para la misma recta.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.24 **
# :class: tip
#
# Considere las rectas: $\mathbf{r}(t) = (2, 0) + t(1, -2)$ y $2x + y = 10$.
#
# a) Determine algebraicamente si las rectas son paralelas.
#
# b) Si se cortan, encuentre el punto de intersección y el valor del parámetro $t$ en ese punto.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.25 **
# :class: tip
#
# Determine el valor de $k \in \mathbb{R}$ para que la recta que pasa por los puntos $(k, 2)$ y $(2, -2)$ sea perpendicular al vector $\mathbf{v} = (2, -1)$.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.26 ***
# :class: tip
#
# Dados los puntos $P = (4, 5)$ y $Q = (1, 2)$, y la recta $\ell: x - 3y = 2$:
#
# a) Escriba la recta $\mathbf{v}(t)$ en forma paramétrica que pasa por $P$ y $Q$.
#
# b) Encuentre el punto $S$ sobre la recta $\ell$ tal que el vector $\vec{SQ}$ sea perpendicular al vector director de $\ell$.
# :::

# %% [markdown]
# ### Producto Punto

# %% [markdown]
# :::{admonition} Ejercicio 1.27 *
# :class: tip
#
# Calcule el producto punto de los siguientes pares de vectores:
#
# a) $\mathbf{u} = (3, 4)$ y $\mathbf{v} = (2, -1)$
#
# b) $\mathbf{u} = (1, 0)$ y $\mathbf{v} = (0, 1)$
#
# c) $\mathbf{u} = (-2, 5)$ y $\mathbf{v} = (10, 4)$
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.28 **
# :class: tip
#
# Encuentre el ángulo entre los vectores $\mathbf{u} = (1, \sqrt{3})$ y $\mathbf{v} = (\sqrt{3}, 1)$.
#
# :::{dropdown} Pista
# Use la fórmula $\cos(\theta) = \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{u}\| \|\mathbf{v}\|}$
# :::
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.29 **
# :class: tip
#
# Encuentre todos los vectores de la forma $(x, 2)$ que sean ortogonales al vector $(4, -3)$.
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.30 **
# :class: tip
#
# Calcule la proyección ortogonal del vector $\mathbf{u} = (4, 3)$ sobre el vector $\mathbf{v} = (1, 0)$.
#
# ¿Cuál es la componente de $\mathbf{u}$ perpendicular a $\mathbf{v}$?
# :::

# %% [markdown]
# :::{admonition} Ejercicio 1.31 ***
# :class: tip
#
# Sean $\mathbf{u} = (3, 1)$ y $\mathbf{v} = (2, 2)$.
#
# a) Calcule $\text{proy}_{\mathbf{v}} \mathbf{u}$ (proyección de $\mathbf{u}$ sobre $\mathbf{v}$).
#
# b) Descomponga $\mathbf{u}$ como suma de un vector paralelo a $\mathbf{v}$ y un vector perpendicular a $\mathbf{v}$.
#
# c) Verifique que estos dos componentes son ortogonales.
# :::

# %% [markdown]
# ---
#
# ## 2. Ejercicios Computacionales
#
# Los siguientes ejercicios requieren el uso de Python y NumPy. Use la celda de código a continuación para importar las bibliotecas necesarias.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# :::{admonition} Ejercicio 2.1 *
# :class: tip
#
# Defina los vectores $\mathbf{v} = (1, 3)$ y $\mathbf{w} = (2, 5)$ en Python utilizando NumPy y realice las siguientes operaciones:
#
# a) Calcule $3(\mathbf{v} + \mathbf{w})$ y $3\mathbf{v} + 3\mathbf{w}$, y verifique que son iguales.
#
# b) Calcule $(5 + \frac{1}{3})\mathbf{v}$ y $5\mathbf{v} + \frac{1}{3}\mathbf{v}$, y verifique que son iguales.
#
# c) Calcule $1 \cdot \mathbf{v}$ y verifique que es igual a $\mathbf{v}$.
# :::

# %%
# Espacio para resolver el ejercicio 2.1

# %% [markdown]
# :::{admonition} Ejercicio 2.2 **
# :class: tip
#
# Escriba una función `es_combinacion_lineal(w, u, v)` que determine si el vector `w` puede expresarse como combinación lineal de `u` y `v`. La función debe retornar `True` o `False`, y en caso afirmativo, imprimir los coeficientes.
#
# Pruebe su función con:
# - $\mathbf{w} = (7, 11)$, $\mathbf{u} = (1, 2)$, $\mathbf{v} = (3, 1)$
# - $\mathbf{w} = (1, 1)$, $\mathbf{u} = (1, 2)$, $\mathbf{v} = (2, 4)$
# :::

# %%
# Espacio para resolver el ejercicio 2.2

# %% [markdown]
# :::{admonition} Ejercicio 2.3 **
# :class: tip
#
# Escriba una función `son_linealmente_independientes(u, v)` que use el determinante para verificar si dos vectores en $\mathbb{R}^2$ son linealmente independientes.
#
# Pruebe su función con varios pares de vectores.
#
# :::{dropdown} Pista
# Use `np.linalg.det()` para calcular el determinante de la matriz $2 \times 2$ formada por los vectores como columnas.
# :::
# :::

# %%
# Espacio para resolver el ejercicio 2.3

# %% [markdown]
# :::{admonition} Ejercicio 2.4 **
# :class: tip
#
# Dada la recta $\mathbf{r}(t) = (1, -2) + t(-3, 4)$:
#
# a) Defina en Python el punto base y el vector director.
#
# b) Escriba una función que, dado un valor de $t$, retorne el punto correspondiente en la recta.
#
# c) Grafique la recta para $t \in [-2, 3]$.
#
# d) Verifique computacionalmente si el punto $(10, -14)$ está en la recta.
# :::

# %%
# Espacio para resolver el ejercicio 2.4

# %% [markdown]
# :::{admonition} Ejercicio 2.5 **
# :class: tip
#
# Escriba una función `distancia_punto_recta(P, P0, d)` que calcule la distancia desde un punto $P$ a una recta definida por un punto $P_0$ y un vector director $\mathbf{d}$.
#
# Use la fórmula basada en proyecciones:
# \(\text{distancia} = \left\| \vec{P_0P} - \text{proy}_{\mathbf{d}} \vec{P_0P} \right\|\)
#
# Pruebe con $P = (3, 4)$, $P_0 = (0, 0)$, $\mathbf{d} = (1, 0)$.
# :::

# %%
# Espacio para resolver el ejercicio 2.5

# %% [markdown]
# :::{admonition} Ejercicio 2.6 **
# :class: tip
#
# Escriba una función `angulo_entre_vectores(u, v)` que calcule el ángulo en grados entre dos vectores.
#
# Pruebe su función calculando el ángulo entre:
# - $(1, 0)$ y $(0, 1)$ (debería ser 90°)
# - $(1, 1)$ y $(1, 0)$ (debería ser 45°)
# - $(1, 0)$ y $(2, 0)$ (debería ser 0°)
# :::

# %%
# Espacio para resolver el ejercicio 2.6

# %% [markdown]
# :::{admonition} Ejercicio 2.7 ***
# :class: tip
#
# Escriba una función `proyeccion_ortogonal(u, v)` que calcule la proyección ortogonal del vector $\mathbf{u}$ sobre el vector $\mathbf{v}$.
#
# Use esta función para descomponer el vector $\mathbf{u} = (5, 3)$ en:
# - Un componente paralelo a $\mathbf{v} = (2, 1)$
# - Un componente perpendicular a $\mathbf{v}$
#
# Verifique que la suma de ambos componentes es igual a $\mathbf{u}$ y que son ortogonales entre sí.
# :::

# %%
# Espacio para resolver el ejercicio 2.7

# %% [markdown]
# :::{admonition} Ejercicio 2.8 ***
# :class: tip
#
# Cree una visualización interactiva que muestre:
# - Dos vectores $\mathbf{u}$ y $\mathbf{v}$ en $\mathbb{R}^2$
# - Su suma $\mathbf{u} + \mathbf{v}$ (usando la regla del paralelogramo)
# - La proyección de $\mathbf{u}$ sobre $\mathbf{v}$
#
# Use `plt.quiver()` para dibujar los vectores.
# :::

# %%
# Espacio para resolver el ejercicio 2.8

# %% [markdown]
# :::{admonition} Ejercicio 2.9 ***
# :class: tip
#
# Escriba un programa que verifique numéricamente si un conjunto dado de puntos forma un subespacio de $\mathbb{R}^2$. El programa debe:
#
# 1. Verificar que el vector cero está en el conjunto.
# 2. Verificar que el conjunto es cerrado bajo la suma (probando varios pares de vectores).
# 3. Verificar que el conjunto es cerrado bajo la multiplicación por escalar (probando varios escalares).
#
# Aplique su programa a:
# - La recta $y = 2x$
# - La recta $y = 2x + 1$
# :::

# %%
# Espacio para resolver el ejercicio 2.9

# %% [markdown]
# ---
#
# ## 3. Problemas de Aplicación

# %% [markdown]
# :::{admonition} Problema 3.1 - Física: Fuerzas **
# :class: tip
#
# Dos fuerzas actúan sobre un objeto:
# - $\mathbf{F}_1 = (30, 40)$ N (Newton)
# - $\mathbf{F}_2 = (-20, 10)$ N
#
# a) Calcule la fuerza resultante $\mathbf{F}_R = \mathbf{F}_1 + \mathbf{F}_2$.
#
# b) Calcule la magnitud de la fuerza resultante.
#
# c) Encuentre el ángulo que forma la fuerza resultante con el eje $x$ positivo.
#
# d) ¿Qué fuerza $\mathbf{F}_3$ se debe aplicar para que el objeto esté en equilibrio?
# :::

# %%
# Espacio para resolver el problema 3.1

# %% [markdown]
# :::{admonition} Problema 3.2 - Física: Trabajo **
# :class: tip
#
# Una fuerza $\mathbf{F} = (15, 20)$ N mueve un objeto desde el punto $A = (1, 2)$ hasta el punto $B = (5, 6)$ (unidades en metros).
#
# a) Calcule el vector desplazamiento $\vec{AB}$.
#
# b) Calcule el trabajo realizado por la fuerza, usando $W = \mathbf{F} \cdot \vec{AB}$.
#
# c) ¿Cuál es la componente de la fuerza en la dirección del desplazamiento?
# :::

# %%
# Espacio para resolver el problema 3.2

# %% [markdown]
# :::{admonition} Problema 3.3 - Geometría: Distancias **
# :class: tip
#
# Un triángulo tiene vértices en $A = (0, 0)$, $B = (4, 0)$ y $C = (2, 3)$.
#
# a) Calcule la longitud de cada lado del triángulo.
#
# b) Calcule el perímetro del triángulo.
#
# c) Encuentre el punto medio de cada lado.
#
# d) Verifique que los tres puntos medios no son colineales.
# :::

# %%
# Espacio para resolver el problema 3.3

# %% [markdown]
# :::{admonition} Problema 3.4 - Navegación ***
# :class: tip
#
# Un barco navega con velocidad propia de 20 km/h hacia el este (dirección $(1, 0)$). Sin embargo, hay una corriente marina de 5 km/h hacia el norte (dirección $(0, 1)$).
#
# a) Exprese la velocidad del barco y la corriente como vectores.
#
# b) Calcule la velocidad resultante del barco.
#
# c) ¿Cuál es la rapidez real del barco?
#
# d) ¿En qué dirección se mueve realmente el barco? (ángulo con respecto al este)
#
# e) Si el barco quiere llegar exactamente al este, ¿en qué dirección debe orientarse?
# :::

# %%
# Espacio para resolver el problema 3.4

# %% [markdown]
# :::{admonition} Problema 3.5 - Gráficos por Computadora ***
# :class: tip
#
# En gráficos por computadora, un sprite tiene su centro en el punto $(3, 2)$ y está orientado en la dirección del vector $(1, 1)$ (normalizado).
#
# a) Calcule el vector unitario en la dirección de orientación.
#
# b) Si el sprite debe mirar hacia un enemigo ubicado en $(7, 5)$, calcule el nuevo vector de dirección.
#
# c) Calcule el ángulo de rotación necesario (en grados).
#
# d) El sprite puede "ver" en un cono de 60° de apertura. ¿Puede ver un objeto ubicado en $(5, 1)$ cuando está orientado hacia $(1, 1)$?
# :::

# %%
# Espacio para resolver el problema 3.5

# %% [markdown]
# :::{admonition} Problema 3.6 - Economía **
# :class: tip
#
# Una empresa produce dos productos: A y B. El vector de precios es $\mathbf{p} = (50, 80)$ (dólares por unidad) y el vector de cantidades vendidas es $\mathbf{q} = (100, 75)$ (unidades).
#
# a) Calcule el ingreso total usando el producto punto $\mathbf{p} \cdot \mathbf{q}$.
#
# b) Si los costos unitarios son $\mathbf{c} = (30, 50)$, calcule el vector de ganancias unitarias.
#
# c) Calcule la ganancia total.
# :::

# %%
# Espacio para resolver el problema 3.6

# %% [markdown]
# ---
#
# ## 4. Desafíos

# %% [markdown]
# :::{admonition} Desafío 4.1 ***
# :class: tip
#
# **Demostración: Desigualdad de Cauchy-Schwarz**
#
# Demuestre que para cualesquiera vectores $\mathbf{u}, \mathbf{v} \in \mathbb{R}^2$:
#
# \(|\mathbf{u} \cdot \mathbf{v}| \leq \|\mathbf{u}\| \|\mathbf{v}\|\)
#
# :::{dropdown} Pista
# Considere el vector $\mathbf{u} - t\mathbf{v}$ para un escalar $t$. Use que $\|\mathbf{u} - t\mathbf{v}\|^2 \geq 0$ para todo $t$.
# :::
# :::

# %% [markdown]
# :::{admonition} Desafío 4.2 ***
# :class: tip
#
# **Demostración: Desigualdad Triangular**
#
# Demuestre que para cualesquiera vectores $\mathbf{u}, \mathbf{v} \in \mathbb{R}^2$:
#
# \(\|\mathbf{u} + \mathbf{v}\| \leq \|\mathbf{u}\| + \|\mathbf{v}\|\)
#
# :::{dropdown} Pista
# Expanda $\|\mathbf{u} + \mathbf{v}\|^2$ y use la desigualdad de Cauchy-Schwarz.
# :::
# :::

# %% [markdown]
# :::{admonition} Desafío 4.3 ***
# :class: tip
#
# **Problema de optimización**
#
# Dado el vector $\mathbf{v} = (3, 4)$, encuentre el vector unitario $\mathbf{u}$ tal que el producto punto $\mathbf{u} \cdot \mathbf{v}$ sea máximo.
#
# Demuestre que el máximo se alcanza cuando $\mathbf{u}$ tiene la misma dirección que $\mathbf{v}$.
# :::

# %% [markdown]
# :::{admonition} Desafío 4.4 ***
# :class: tip
#
# **Reflexión sobre una recta**
#
# Sea $\ell$ la recta que pasa por el origen con vector director $\mathbf{d} = (1, 1)$.
#
# a) Derive una fórmula para la reflexión de un vector $\mathbf{v}$ con respecto a la recta $\ell$.
#
# b) Calcule la reflexión del vector $(3, 1)$ con respecto a $\ell$.
#
# c) Verifique que la reflexión preserva la norma del vector.
#
# :::{dropdown} Pista
# Use la proyección: $\mathbf{v}_{\text{ref}} = 2 \cdot \text{proy}_{\mathbf{d}} \mathbf{v} - \mathbf{v}$
# :::
# :::

# %% [markdown]
# :::{admonition} Desafío 4.5 ***
# :class: tip
#
# **Bases y cambio de coordenadas**
#
# Sean $\mathbf{e}_1 = (1, 0)$, $\mathbf{e}_2 = (0, 1)$ la base estándar de $\mathbb{R}^2$, y sea $\mathcal{B} = \{\mathbf{b}_1, \mathbf{b}_2\}$ con $\mathbf{b}_1 = (1, 1)$ y $\mathbf{b}_2 = (1, -1)$ otra base.
#
# a) Verifique que $\mathcal{B}$ es efectivamente una base de $\mathbb{R}^2$.
#
# b) Exprese el vector $\mathbf{v} = (5, 3)$ en términos de la base $\mathcal{B}$. Es decir, encuentre $\alpha, \beta$ tales que $\mathbf{v} = \alpha \mathbf{b}_1 + \beta \mathbf{b}_2$.
#
# c) Si un vector tiene coordenadas $(2, -1)$ en la base $\mathcal{B}$, ¿cuáles son sus coordenadas en la base estándar?
# :::

# %%
# Espacio para resolver los desafíos (opcional)
