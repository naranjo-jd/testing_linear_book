# %% [markdown]
# # Quiz: Operaciones, Subespacios y Rectas en $\mathbb{R}^2$
#
# Pon a prueba tus conocimientos sobre operaciones básicas con vectores, subespacios vectoriales y rectas paramétricas en el plano.

# %%
# cell_metadata: {"tags": ["remove-input"]}
from jupyterquiz import display_quiz

quiz_algebra = [
    {
        "question": r"¿Cuál de las siguientes condiciones es INDISPENSABLE para que un conjunto $W \subseteq \mathbb{R}^2$ sea un subespacio vectorial?",
        "type": "multiple_choice",
        "answers": [
            {"answer": r"Que el vector nulo $(0,0)$ pertenezca a $W$.", "correct": True, "feedback": "¡Correcto! Es la condición de existencia del elemento neutro."},
            {"answer": r"Que contenga al menos dos vectores independientes.", "correct": False, "feedback": "Incorrecto. El subespacio $\{(0,0)\}$ es válido y tiene dimensión 0."},
            {"answer": r"Que todos sus vectores tengan componentes positivas.", "correct": False, "feedback": "Incorrecto. Debe permitir escalares negativos."}
        ]
    },
    {
        "question": r"Dada la recta paramétrica $L: (x, y) = (1, 2) + t(3, -1)$, ¿cuál es su vector director?",
        "type": "multiple_choice",
        "answers": [
            {"code": "(3, -1)", "correct": True, "feedback": "¡Exacto! Indica la dirección de la recta."},
            {"code": "(1, 2)", "correct": False, "feedback": "No, ese es el punto por donde pasa la recta."}
        ]
    },
    {
        "question": r"¿Cuál de estos conjuntos representa una recta que es un subespacio de $\mathbb{R}^2$?",
        "type": "multiple_choice",
        "answers": [
            {"answer": r"$y = 2x$", "correct": True, "feedback": "Correcto. Al pasar por el origen $(0,0)$ cumple con ser subespacio."},
            {"answer": r"$y = 2x + 1$", "correct": False, "feedback": "Incorrecto. No pasa por el origen."}
        ]
    },
    {
        "question": r"Si $u = (1, 1)$ y $v = (-1, 1)$, ¿cuál es el resultado de $u \cdot v$?",
        "type": "multiple_choice",
        "answers": [
            {"answer": r"$0$ (los vectores son perpendiculares)", "correct": True, "feedback": r"Correcto. $1(-1) + 1(1) = 0$."},
            {"answer": r"$2$", "correct": False, "feedback": "Revisa los signos de las componentes."}
        ]
    },
    {
        "question": r"El conjunto $S = \{ (x, y) \in \mathbb{R}^2 : x \ge 0, y \ge 0 \}$ ¿es un subespacio vectorial?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "No, falla la clausura ante escalares negativos.", "correct": True, "feedback": "Correcto. El opuesto de un vector en el primer cuadrante no está en $S$."},
            {"answer": "Sí, porque contiene al origen.", "correct": False, "feedback": "Falta la propiedad de multiplicación por escalar negativo."}
        ]
    },
    {
        "question": r"¿Cuál es el resultado de la combinación lineal $3u - 2v$ si $u = (4, 2)$ y $v = (1, 5)$?",
        "type": "multiple_choice",
        "answers": [
            {"code": "(10, -4)", "correct": True, "feedback": r"Correcto: $(12,6) - (2,10) = (10,-4)$."},
            {"code": "(11, 16)", "correct": False, "feedback": "Revisa la resta de las segundas componentes."}
        ]
    },
    {
        "question": r"Si una recta tiene la ecuación general $2x - 3y = 0$, ¿cuál es su vector director?",
        "type": "multiple_choice",
        "answers": [
            {"code": "(3, 2)", "correct": True, "feedback": "Correcto. El vector director es perpendicular al normal $(2,-3)$."},
            {"code": "(2, -3)", "correct": False, "feedback": "Ese es el vector normal a la recta."}
        ]
    },
    {
        "question": r"¿Qué par de vectores forman una base para $\mathbb{R}^2$?",
        "type": "multiple_choice",
        "answers": [
            {"answer": r"$(1, 0)$ y $(0, 1)$", "correct": True, "feedback": "Correcto. Son linealmente independientes y generan el plano."},
            {"answer": r"$(1, 2)$ y $(2, 4)$", "correct": False, "feedback": "Incorrecto. Son vectores paralelos."}
        ]
    },
    {
        "question": r"En la recta $P = A + tV$, ¿qué sucede si el vector director $V$ es el vector nulo $(0,0)$?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "El conjunto se reduce a un solo punto ($A$).", "correct": True, "feedback": "Correcto. Sin dirección, no hay recta, solo el punto inicial."},
            {"answer": "La recta pasa por el origen.", "correct": False, "feedback": "No, simplemente deja de ser una recta."}
        ]
    },
    {
        "question": r"Si un subespacio de $\mathbb{R}^2$ contiene a dos vectores linealmente independientes, ¿qué subespacio es?",
        "type": "multiple_choice",
        "answers": [
            {"answer": r"Todo el espacio $\mathbb{R}^2$.", "correct": True, "feedback": "Exacto. Dos vectores independientes en dimensión 2 generan todo el espacio."},
            {"answer": r"Una recta que pasa por el origen.", "correct": False, "feedback": "Una recta solo requiere un vector independiente."}
        ]
    }
]

display_quiz(quiz_algebra)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\{'
# <>:10: SyntaxWarning: invalid escape sequence '\{'
# /tmp/ipykernel_53578/1222744603.py:10: SyntaxWarning: invalid escape sequence '\{'
#   {"answer": r"Que contenga al menos dos vectores independientes.", "correct": False, "feedback": "Incorrecto. El subespacio $\{(0,0)\}$ es válido y tiene dimensión 0."},
# <div id="XRrktrvWLsws" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #XRrktrvWLsws {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
# ...
